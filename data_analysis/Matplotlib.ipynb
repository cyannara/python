# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = [10, 20, 30, 40, 50]
plt.plot(data)

# %%
# 상관분석, 상관계수 : ex)키가크면 발이크다
# 양의 상관관계, 음의 상관관계

x_values = [1, 2, 3, 4, 5]
y_values = [10, 30, 20, 40, 50]
# plt.scatter(x_values, y_values)

df = pd.DataFrame({'a': x_values, 'b':y_values})
corr = df['a'].corr(df['b'])
print(corr)
print(df.corr())

# plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.plot(x_values, y_values, marker='o', linestyle='--')
# plt.title('한글 제목')
# plt.xlabel('x-Axis Label')
# plt.ylabel('Y-Axis Label')
# plt.grid(True)

s = pd.Series(x_values)
s.ca
# Out:
# 0.8999999999999999
#      a    b
# a  1.0  0.9
# b  0.9  1.0
